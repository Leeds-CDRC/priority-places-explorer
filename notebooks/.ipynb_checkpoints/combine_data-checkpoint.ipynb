# %%
import pandas as pd
data_directory = '../../../Data/PriorityPlacesData/'

# %%
scot_dz = pd.read_csv(data_directory + 'SG_DataZones_Centroids_2011.csv')
ew_lsoa = pd.read_csv(data_directory + 'Lower_layer_Super_Output_Areas_(December_2011)_Population_Weighted_Centroids_WGS.csv')
pp_data = pd.read_csv(data_directory + 'priority_places_v0_1_ranked_domains.csv')

# %%
pp_data = pp_data.merge(ew_lsoa, left_on='geo_code', right_on='lsoa11cd', how='left')

# %%
pp_data = pp_data.merge(scot_dz, left_on='geo_code', right_on='DataZone', how='left')

# %%
pp_data['longitude'] = pp_data['longitude_x'].fillna(pp_data['longitude_y'])
pp_data['latitude'] = pp_data['latitude_x'].fillna(pp_data['latitude_y'])

# %%
pp_data[['geo_code', 'longitude', 'latitude'] + pp_data.columns[pp_data.columns.str.startswith('domain')].tolist()]

# %%
pp_data = pp_data[['geo_code', 'longitude', 'latitude'] + pp_data.columns[pp_data.columns.str.startswith('domain')].tolist()]

# %%
pp_data.to_csv(data_directory + 'priority_places_v0_1_ranked_domains_WGS.csv', index=False)
# Out:
#         geo_code  longitude   latitude  domain_supermarket_proximity  \
# 0      E01003513   0.045915  51.513348                       19099.0
# 1      E01003630   0.013900  51.533718                       32961.0
# 2      E01003617   0.001566  51.545061                         882.0
# 3      E01003497   0.008449  51.520488                       12278.0
# 4      E01003499   0.021817  51.523869                        7163.0
# ...          ...        ...        ...                           ...
# 41723  S01012412  -1.449147  60.487709                       41714.0
# 41724  S01012413  -1.076407  60.598739                       41722.0
# 41725  S01012414  -0.860016  60.757838                       41727.0
# 41726  S01012415  -1.019186  60.344683                       41665.0
# 41727  S01012416  -0.994725  60.364766                       41681.0
#
#        domain_supermarket_transport  domain_ecommerce_access  \
# 0                           12059.0                   1903.0
# 1                           12972.0                  16658.0
# 2                           10894.0                     34.0
# 3                           13103.0                  16658.0
# 4                            9211.0                  34483.0
# ...                             ...                      ...
# 41723                       40697.0                  41333.0
# 41724                       41722.0                  41333.0
# 41725                       41728.0                  41382.0
# 41726                       41720.0                  41333.0
# 41727                       41721.0                  41333.0
#
#        domain_socio_demographic  domain_nonsupermarket_proximity  \
# 0                        4056.0                          11710.0
# 1                       37278.0                           6479.0
# 2                       41247.0                           1130.0
# 3                       34297.0                          13324.0
# 4                       41224.0                           7488.0
# ...                         ...                              ...
# 41723                    4756.0                          41726.0
# 41724                   18151.0                          41727.0
# 41725                   22289.0                          41728.0
# 41726                    6493.0                          41722.0
# 41727                   14035.0                          41723.0
#
#        domain_food_for_families  domain_fuel_poverty
# 0                         435.0              36259.0
# 1                        5801.0              40167.0
# 2                         280.0              38402.0
# 3                       10014.0              40336.0
# 4                       11969.0              38845.0
# ...                         ...                  ...
# 41723                   41629.0              40552.0
# 41724                   41684.0              40552.0
# 41725                   41727.0              40552.0
# 41726                   40970.0              40552.0
# 41727                   41277.0              40552.0
#
# [41728 rows x 10 columns]
